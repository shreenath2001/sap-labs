# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/hackerearth-employee-burnout-challenge/sample_submission.csv
# /kaggle/input/hackerearth-employee-burnout-challenge/train.csv
# /kaggle/input/hackerearth-employee-burnout-challenge/test.csv

# %%
import numpy as np
import pandas as pd

import re
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import optuna
import xgboost as xgb

from sklearn.metrics import r2_score
import pickle

# %%
train_df = pd.read_csv('/kaggle/input/hackerearth-employee-burnout-challenge/train.csv', header = 0)
test_df = pd.read_csv('/kaggle/input/hackerearth-employee-burnout-challenge/test.csv', header = 0)
train_df.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      2008-09-30  Female      Service
# 1      fffe3700360033003500      2008-11-30    Male      Service
# 2  fffe31003300320037003900      2008-03-10  Female      Product
# 3  fffe32003400380032003900      2008-11-03    Male      Service
# 4  fffe31003900340031003600      2008-07-24  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No          2.0                  3.0                   3.8
# 1                 Yes          1.0                  2.0                   5.0
# 2                 Yes          2.0                  NaN                   5.8
# 3                 Yes          1.0                  1.0                   2.6
# 4                  No          3.0                  7.0                   6.9
#
#    Burn Rate
# 0       0.16
# 1       0.36
# 2       0.49
# 3       0.20
# 4       0.52

# %%
train_df['year'] = pd.DatetimeIndex(train_df['Date of Joining']).year

# %%
train_df['year'].value_counts()
# Out:
# 2008    22750
# Name: year, dtype: int64

# %%
train_df.drop(['Employee ID', 'Date of Joining', 'year'], axis = 1, inplace = True)
test_df.drop(['Employee ID', 'Date of Joining'], axis = 1, inplace = True)

# %%
train_df.head()
# Out:
#    Gender Company Type WFH Setup Available  Designation  Resource Allocation  \
# 0  Female      Service                  No          2.0                  3.0
# 1    Male      Service                 Yes          1.0                  2.0
# 2  Female      Product                 Yes          2.0                  NaN
# 3    Male      Service                 Yes          1.0                  1.0
# 4  Female      Service                  No          3.0                  7.0
#
#    Mental Fatigue Score  Burn Rate
# 0                   3.8       0.16
# 1                   5.0       0.36
# 2                   5.8       0.49
# 3                   2.6       0.20
# 4                   6.9       0.52

# %%
train_df.shape
# Out:
# (22750, 7)

# %%
train_df.columns
# Out:
# Index(['Gender', 'Company Type', 'WFH Setup Available', 'Designation',
#        'Resource Allocation', 'Mental Fatigue Score', 'Burn Rate'],
#       dtype='object')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                22750 non-null  object
#  1   Company Type          22750 non-null  object
#  2   WFH Setup Available   22750 non-null  object
#  3   Designation           22750 non-null  float64
#  4   Resource Allocation   21369 non-null  float64
#  5   Mental Fatigue Score  20633 non-null  float64
#  6   Burn Rate             21626 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 1.2+ MB

# %%
train_df.isnull().sum()
# Out:
# Gender                     0
# Company Type               0
# WFH Setup Available        0
# Designation                0
# Resource Allocation     1381
# Mental Fatigue Score    2117
# Burn Rate               1124
# dtype: int64

# %%
train_df.describe().T
# Out:
#                         count      mean       std  min   25%   50%   75%   max
# Designation           22750.0  2.178725  1.135145  0.0  1.00  2.00  3.00   5.0
# Resource Allocation   21369.0  4.481398  2.047211  1.0  3.00  4.00  6.00  10.0
# Mental Fatigue Score  20633.0  5.728188  1.920839  0.0  4.60  5.90  7.10  10.0
# Burn Rate             21626.0  0.452005  0.198226  0.0  0.31  0.45  0.59   1.0

# %%
train_df['Resource Allocation'].fillna(4.0, inplace = True)
train_df['Mental Fatigue Score'].fillna(5.7, inplace = True)
train_df['Burn Rate'].fillna(0.45, inplace = True)

# %%
train_df.isnull().sum()
# Out:
# Gender                  0
# Company Type            0
# WFH Setup Available     0
# Designation             0
# Resource Allocation     0
# Mental Fatigue Score    0
# Burn Rate               0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# Gender                  0
# Company Type            0
# WFH Setup Available     0
# Designation             0
# Resource Allocation     0
# Mental Fatigue Score    0
# dtype: int64

# %%
train_df['Gender'].value_counts()
# Out:
# Female    11908
# Male      10842
# Name: Gender, dtype: int64

# %%
train_df['WFH Setup Available'].value_counts()
# Out:
# Yes    12290
# No     10460
# Name: WFH Setup Available, dtype: int64

# %%
train_df['Company Type'].value_counts()
# Out:
# Service    14833
# Product     7917
# Name: Company Type, dtype: int64

# %%
cleanup_cols = {"Gender":     {"Female": 0, "Male": 1},
                "Company Type": {"Service": 0, "Product": 1},
                 "WFH Setup Available": {"Yes": 0, "No": 1}}

# %%
train_df = train_df.replace(cleanup_cols)
train_df.head()
# Out:
#    Gender  Company Type  WFH Setup Available  Designation  \
# 0       0             0                    1          2.0
# 1       1             0                    0          1.0
# 2       0             1                    0          2.0
# 3       1             0                    0          1.0
# 4       0             0                    1          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                  3.0                   3.8       0.16
# 1                  2.0                   5.0       0.36
# 2                  4.0                   5.8       0.49
# 3                  1.0                   2.6       0.20
# 4                  7.0                   6.9       0.52

# %%
test_df = test_df.replace(cleanup_cols)
test_df.head()
# Out:
#    Gender  Company Type  WFH Setup Available  Designation  \
# 0       0             0                    1          2.0
# 1       0             1                    0          1.0
# 2       1             1                    0          1.0
# 3       0             0                    1          3.0
# 4       0             1                    1          2.0
#
#    Resource Allocation  Mental Fatigue Score
# 0                  5.0                   7.7
# 1                  2.0                   5.2
# 2                  3.0                   5.9
# 3                  6.0                   4.6
# 4                  5.0                   6.4

# %%
feature_cols = train_df.drop(['Burn Rate'], axis=1).columns
x = train_df[feature_cols]
y = train_df['Burn Rate']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
clf = xgb.XGBRegressor(random_state = 42)
clf.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=2, num_parallel_tree=1, random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
predictions = clf.predict(x_test)
errors = abs(predictions - y_test)
print('Mean Absolute Error:', round(np.mean(errors), 3))
# Out:
# Mean Absolute Error: 0.054

# %%
def objective(trial,data=x,target=y):
    
    train_x, test_x, train_y, test_y = train_test_split(data, target, test_size=0.15,random_state=42)
    
    # To select which parameters to optimize, please look at the XGBoost documentation:
    # https://xgboost.readthedocs.io/en/latest/parameter.html
    param = {
        'tree_method':'gpu_hist',  # Use GPU acceleration
        'lambda': trial.suggest_loguniform(
            'lambda', 1e-3, 10.0
        ),
        'alpha': trial.suggest_loguniform(
            'alpha', 1e-3, 10.0
        ),
        'colsample_bytree': trial.suggest_categorical(
            'colsample_bytree', [0.5,0.6,0.7,0.8,0.9,1.0]
        ),
        'subsample': trial.suggest_categorical(
            'subsample', [0.6,0.7,0.8,1.0]
        ),
        'learning_rate': trial.suggest_categorical(
            'learning_rate', [0.008,0.009,0.01,0.012,0.014,0.016,0.018, 0.02]
        ),
        'n_estimators': trial.suggest_categorical(
            "n_estimators", [150, 200, 300, 3000]
        ),
        'max_depth': trial.suggest_categorical(
            'max_depth', [4,5,7,9,11,13,15,17]
        ),
        'random_state': 42,
        'min_child_weight': trial.suggest_int(
            'min_child_weight', 1, 300
        ),
    }
    model = xgb.XGBRegressor(**param)  
    
    model.fit(train_x,train_y,eval_set=[(test_x,test_y)],early_stopping_rounds=100,verbose=False)
    
    preds = model.predict(test_x)
    
    rmse = mean_squared_error(test_y, preds,squared=False)
    
    return rmse

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2021-05-15 10:54:14,918] A new study created in memory with name: no-name-d765944c-7814-4b22-a72a-442bcabf549b
# [I 2021-05-15 10:54:23,010] Trial 0 finished with value: 0.07201447563605116 and parameters: {'lambda': 0.026251202097649265, 'alpha': 0.8832358551224228, 'colsample_bytree': 0.9, 'subsample': 0.8, 'learning_rate': 0.009, 'n_estimators': 3000, 'max_depth': 13, 'min_child_weight': 215}. Best is trial 0 with value: 0.07201447563605116.
# [I 2021-05-15 10:54:23,459] Trial 1 finished with value: 0.07827512638810963 and parameters: {'lambda': 0.00914156403527688, 'alpha': 3.085294911554924, 'colsample_bytree': 0.8, 'subsample': 0.7, 'learning_rate': 0.012, 'n_estimators': 200, 'max_depth': 13, 'min_child_weight': 297}. Best is trial 0 with value: 0.07201447563605116.
# [I 2021-05-15 10:54:23,908] Trial 2 finished with value: 0.07506079777795903 and parameters: {'lambda': 0.012065039532697408, 'alpha': 3.8373539909030008, 'colsample_bytree': 0.9, 'subsample': 0.6, 'learning_rate': 0.014, 'n_estimators': 200, 'max_depth': 7, 'min_child_weight': 172}. Best is trial 0 with value: 0.07201447563605116.
# [I 2021-05-15 10:54:27,756] Trial 3 finished with value: 0.07132339223374581 and parameters: {'lambda': 0.007228813553876135, 'alpha': 0.7725910193215934, 'colsample_bytree': 1.0, 'subsample': 1.0, 'learning_rate': 0.012, 'n_estimators': 3000, 'max_depth': 11, 'min_child_weight': 136}. Best is trial 3 with value: 0.07132339223374581.
# [I 2021-05-15 10:54:28,321] Trial 4 finished with value: 0.09053645171153003 and parameters: {'lambda': 0.025627980121039687, 'alpha': 0.9177379284127095, 'colsample_bytree': 1.0, 'subsample': 0.6, 'learning_rate': 0.008, 'n_estimators': 150, 'max_depth': 7, 'min_child_weight': 1}. Best is trial 3 with value: 0.07132339223374581.
# [I 2021-05-15 10:54:29,091] Trial 5 finished with value: 0.08561809876482616 and parameters: {'lambda': 0.056442452455616576, 'alpha': 0.004724260706351188, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.012, 'n_estimators': 150, 'max_depth': 11, 'min_child_weight': 117}. Best is trial 3 with value: 0.07132339223374581.
# [I 2021-05-15 10:54:31,665] Trial 6 finished with value: 0.0725954454476139 and parameters: {'lambda': 0.005904398166465035, 'alpha': 0.1401504993348356, 'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.014, 'n_estimators': 3000, 'max_depth': 9, 'min_child_weight': 185}. Best is trial 3 with value: 0.07132339223374581.
# [I 2021-05-15 10:54:32,305] Trial 7 finished with value: 0.07608598088338318 and parameters: {'lambda': 0.040566588197277785, 'alpha': 0.001809764114478197, 'colsample_bytree': 0.7, 'subsample': 0.6, 'learning_rate': 0.018, 'n_estimators': 150, 'max_depth': 17, 'min_child_weight': 219}. Best is trial 3 with value: 0.07132339223374581.
# [I 2021-05-15 10:54:34,357] Trial 8 finished with value: 0.07283847081465637 and parameters: {'lambda': 6.288096408219461, 'alpha': 6.334969233380611, 'colsample_bytree': 0.7, 'subsample': 1.0, 'learning_rate': 0.012, 'n_estimators': 3000, 'max_depth': 5, 'min_child_weight': 127}. Best is trial 3 with value: 0.07132339223374581.
# [I 2021-05-15 10:54:34,834] Trial 9 finished with value: 0.08253201972147281 and parameters: {'lambda': 0.5447550113665296, 'alpha': 6.09678491753506, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.008, 'n_estimators': 300, 'max_depth': 4, 'min_child_weight': 113}. Best is trial 3 with value: 0.07132339223374581.
# [I 2021-05-15 10:54:46,390] Trial 10 finished with value: 0.07204328580039532 and parameters: {'lambda': 0.0013455562071761587, 'alpha': 0.027604720199571005, 'colsample_bytree': 1.0, 'subsample': 1.0, 'learning_rate': 0.01, 'n_estimators': 3000, 'max_depth': 11, 'min_child_weight': 18}. Best is trial 3 with value: 0.07132339223374581.
# [I 2021-05-15 10:54:54,992] Trial 11 finished with value: 0.07245649269522415 and parameters: {'lambda': 0.3257881720234556, 'alpha': 0.3266446566095046, 'colsample_bytree': 0.9, 'subsample': 0.8, 'learning_rate': 0.009, 'n_estimators': 3000, 'max_depth': 15, 'min_child_weight': 254}. Best is trial 3 with value: 0.07132339223374581.
# [I 2021-05-15 10:54:58,279] Trial 12 finished with value: 0.07102074001106419 and parameters: {'lambda': 0.001563985199718562, 'alpha': 0.6304303067420237, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.02, 'n_estimators': 3000, 'max_depth': 13, 'min_child_weight': 58}. Best is trial 12 with value: 0.07102074001106419.
# [I 2021-05-15 10:55:01,858] Trial 13 finished with value: 0.07137881571263506 and parameters: {'lambda': 0.0018949896281970327, 'alpha': 0.04983063131821923, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.02, 'n_estimators': 3000, 'max_depth': 11, 'min_child_weight': 53}. Best is trial 12 with value: 0.07102074001106419.
# [I 2021-05-15 10:55:03,830] Trial 14 finished with value: 0.0711746669557177 and parameters: {'lambda': 0.002839824318495923, 'alpha': 0.7561959924050843, 'colsample_bytree': 1.0, 'subsample': 1.0, 'learning_rate': 0.016, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 68}. Best is trial 12 with value: 0.07102074001106419.
# [I 2021-05-15 10:55:06,381] Trial 15 finished with value: 0.07120787891344475 and parameters: {'lambda': 0.0012241112437633389, 'alpha': 0.20114190090633763, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.016, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 64}. Best is trial 12 with value: 0.07102074001106419.
# [I 2021-05-15 10:55:07,779] Trial 16 finished with value: 0.07137647741592724 and parameters: {'lambda': 0.0019945253601605243, 'alpha': 1.5995112393107407, 'colsample_bytree': 1.0, 'subsample': 1.0, 'learning_rate': 0.016, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 69}. Best is trial 12 with value: 0.07102074001106419.
# [I 2021-05-15 10:55:10,335] Trial 17 finished with value: 0.07188441211081217 and parameters: {'lambda': 0.14989477364651613, 'alpha': 0.01573521830683836, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.02, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 34}. Best is trial 12 with value: 0.07102074001106419.
# [I 2021-05-15 10:55:11,581] Trial 18 finished with value: 0.07261044912442384 and parameters: {'lambda': 2.2625543251498508, 'alpha': 0.3944945109434578, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.016, 'n_estimators': 300, 'max_depth': 17, 'min_child_weight': 94}. Best is trial 12 with value: 0.07102074001106419.
# [I 2021-05-15 10:55:12,095] Trial 19 finished with value: 0.07232340309031045 and parameters: {'lambda': 0.0030622081982147327, 'alpha': 0.07021772248513322, 'colsample_bytree': 0.8, 'subsample': 1.0, 'learning_rate': 0.02, 'n_estimators': 200, 'max_depth': 5, 'min_child_weight': 79}. Best is trial 12 with value: 0.07102074001106419.
# [I 2021-05-15 10:55:12,631] Trial 20 finished with value: 0.07345584094251638 and parameters: {'lambda': 0.0037738815637516506, 'alpha': 1.8490996004931444, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.01, 'n_estimators': 300, 'max_depth': 4, 'min_child_weight': 4}. Best is trial 12 with value: 0.07102074001106419.
# [I 2021-05-15 10:55:15,449] Trial 21 finished with value: 0.0711861263221138 and parameters: {'lambda': 0.0011178503255930006, 'alpha': 0.20600257335871103, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.016, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 52}. Best is trial 12 with value: 0.07102074001106419.
# [I 2021-05-15 10:55:18,138] Trial 22 finished with value: 0.07098840712062145 and parameters: {'lambda': 0.0010657727946358625, 'alpha': 0.33860207714918455, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.016, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 41}. Best is trial 22 with value: 0.07098840712062145.
# [I 2021-05-15 10:55:21,065] Trial 23 finished with value: 0.07086004976420605 and parameters: {'lambda': 0.001029078601455882, 'alpha': 0.4986209509535147, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.016, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 29}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:24,263] Trial 24 finished with value: 0.07093044167174574 and parameters: {'lambda': 0.0010005421790321683, 'alpha': 0.3532300808694339, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.018, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 27}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:26,986] Trial 25 finished with value: 0.07114481846952314 and parameters: {'lambda': 0.0011068390183327534, 'alpha': 0.10972609363071772, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.018, 'n_estimators': 300, 'max_depth': 9, 'min_child_weight': 23}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:30,100] Trial 26 finished with value: 0.07097241348760772 and parameters: {'lambda': 0.015691912920223355, 'alpha': 0.3489760230023014, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.018, 'n_estimators': 300, 'max_depth': 15, 'min_child_weight': 35}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:39,323] Trial 27 finished with value: 0.07194105810237178 and parameters: {'lambda': 0.016138745993481852, 'alpha': 0.03877675786511589, 'colsample_bytree': 0.7, 'subsample': 0.8, 'learning_rate': 0.018, 'n_estimators': 300, 'max_depth': 15, 'min_child_weight': 3}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:41,455] Trial 28 finished with value: 0.07152746000512171 and parameters: {'lambda': 0.11326537658679191, 'alpha': 0.01803849823472653, 'colsample_bytree': 0.8, 'subsample': 0.8, 'learning_rate': 0.018, 'n_estimators': 300, 'max_depth': 15, 'min_child_weight': 99}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:42,478] Trial 29 finished with value: 0.07258411735325963 and parameters: {'lambda': 0.016726889474109063, 'alpha': 1.6597337920708233, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.018, 'n_estimators': 300, 'max_depth': 15, 'min_child_weight': 25}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:43,593] Trial 30 finished with value: 0.0723080122741492 and parameters: {'lambda': 0.006296915877655654, 'alpha': 0.43065523619282176, 'colsample_bytree': 0.5, 'subsample': 0.8, 'learning_rate': 0.018, 'n_estimators': 300, 'max_depth': 15, 'min_child_weight': 92}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:46,711] Trial 31 finished with value: 0.07102346619912289 and parameters: {'lambda': 0.0036720256583955132, 'alpha': 0.2439533788895003, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.016, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 37}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:50,166] Trial 32 finished with value: 0.07190938760156956 and parameters: {'lambda': 0.004488291775202426, 'alpha': 0.11468061545543898, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.009, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 40}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:51,912] Trial 33 finished with value: 0.07096619104370476 and parameters: {'lambda': 0.011212809759604597, 'alpha': 0.512849099352691, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.018, 'n_estimators': 200, 'max_depth': 13, 'min_child_weight': 13}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:52,582] Trial 34 finished with value: 0.07225831431752039 and parameters: {'lambda': 0.010200425572081135, 'alpha': 3.1271363204319274, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.018, 'n_estimators': 200, 'max_depth': 7, 'min_child_weight': 1}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:53,999] Trial 35 finished with value: 0.07134486212253931 and parameters: {'lambda': 0.05701219762545047, 'alpha': 1.21195645001084, 'colsample_bytree': 1.0, 'subsample': 0.6, 'learning_rate': 0.018, 'n_estimators': 200, 'max_depth': 13, 'min_child_weight': 14}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:54,651] Trial 36 finished with value: 0.07339276154660244 and parameters: {'lambda': 0.02955393571328607, 'alpha': 0.6153701318600018, 'colsample_bytree': 0.8, 'subsample': 0.8, 'learning_rate': 0.018, 'n_estimators': 200, 'max_depth': 13, 'min_child_weight': 159}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:56,131] Trial 37 finished with value: 0.0717714946724733 and parameters: {'lambda': 0.017122652440381927, 'alpha': 0.17606047865738056, 'colsample_bytree': 0.9, 'subsample': 0.8, 'learning_rate': 0.014, 'n_estimators': 200, 'max_depth': 9, 'min_child_weight': 13}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:56,807] Trial 38 finished with value: 0.07277319767613782 and parameters: {'lambda': 0.008536430918329431, 'alpha': 0.07627180864320225, 'colsample_bytree': 1.0, 'subsample': 0.6, 'learning_rate': 0.018, 'n_estimators': 150, 'max_depth': 7, 'min_child_weight': 85}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:58,070] Trial 39 finished with value: 0.08043436197985018 and parameters: {'lambda': 0.07646998767018848, 'alpha': 0.9083578680692618, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.008, 'n_estimators': 200, 'max_depth': 17, 'min_child_weight': 31}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:55:58,389] Trial 40 finished with value: 0.07654346588445744 and parameters: {'lambda': 0.21614854898187885, 'alpha': 2.5394769899696406, 'colsample_bytree': 0.7, 'subsample': 0.8, 'learning_rate': 0.018, 'n_estimators': 150, 'max_depth': 5, 'min_child_weight': 277}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:56:00,905] Trial 41 finished with value: 0.0710001189237716 and parameters: {'lambda': 0.0022489181556733574, 'alpha': 0.3974451531393918, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.016, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 42}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:56:05,883] Trial 42 finished with value: 0.07134235131267563 and parameters: {'lambda': 0.027808855452658484, 'alpha': 0.2930479507810541, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.012, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 1}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:56:07,911] Trial 43 finished with value: 0.07107260220195291 and parameters: {'lambda': 0.0010554852589921809, 'alpha': 0.59100678463212, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.016, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 52}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:56:08,277] Trial 44 finished with value: 0.07458764763626413 and parameters: {'lambda': 0.005859412157823536, 'alpha': 0.15375694222192307, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.014, 'n_estimators': 200, 'max_depth': 4, 'min_child_weight': 201}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:56:09,747] Trial 45 finished with value: 0.07187144348515746 and parameters: {'lambda': 0.7264939688705403, 'alpha': 1.2093551854858093, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.01, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 20}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:56:11,487] Trial 46 finished with value: 0.07234539852921902 and parameters: {'lambda': 0.002306354222085092, 'alpha': 0.48715929977113204, 'colsample_bytree': 0.9, 'subsample': 0.8, 'learning_rate': 0.009, 'n_estimators': 300, 'max_depth': 15, 'min_child_weight': 45}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:56:11,917] Trial 47 finished with value: 0.10120718847437958 and parameters: {'lambda': 0.042213461597964845, 'alpha': 0.9469406815884541, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.008, 'n_estimators': 150, 'max_depth': 13, 'min_child_weight': 74}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:56:12,593] Trial 48 finished with value: 0.073701442407374 and parameters: {'lambda': 0.011354495811832038, 'alpha': 9.510893223249926, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.018, 'n_estimators': 300, 'max_depth': 11, 'min_child_weight': 139}. Best is trial 23 with value: 0.07086004976420605.
# [I 2021-05-15 10:56:13,541] Trial 49 finished with value: 0.0744124901816956 and parameters: {'lambda': 0.0016458642674724712, 'alpha': 0.27009255383136554, 'colsample_bytree': 0.5, 'subsample': 0.8, 'learning_rate': 0.016, 'n_estimators': 200, 'max_depth': 13, 'min_child_weight': 12}. Best is trial 23 with value: 0.07086004976420605.
# Number of finished trials: 50
# Best trial: {'lambda': 0.001029078601455882, 'alpha': 0.4986209509535147, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.016, 'n_estimators': 300, 'max_depth': 13, 'min_child_weight': 29}

# %%
study.trials_dataframe().head()
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.072014 2021-05-15 10:54:14.923109 2021-05-15 10:54:23.009836
# 1       1  0.078275 2021-05-15 10:54:23.013689 2021-05-15 10:54:23.458320
# 2       2  0.075061 2021-05-15 10:54:23.462102 2021-05-15 10:54:23.908087
# 3       3  0.071323 2021-05-15 10:54:23.912181 2021-05-15 10:54:27.755965
# 4       4  0.090536 2021-05-15 10:54:27.757499 2021-05-15 10:54:28.320288
#
#                 duration  params_alpha  params_colsample_bytree  \
# 0 0 days 00:00:08.086727      0.883236                      0.9
# 1 0 days 00:00:00.444631      3.085295                      0.8
# 2 0 days 00:00:00.445985      3.837354                      0.9
# 3 0 days 00:00:03.843784      0.772591                      1.0
# 4 0 days 00:00:00.562789      0.917738                      1.0
#
#    params_lambda  params_learning_rate  params_max_depth  \
# 0       0.026251                 0.009                13
# 1       0.009142                 0.012                13
# 2       0.012065                 0.014                 7
# 3       0.007229                 0.012                11
# 4       0.025628                 0.008                 7
#
#    params_min_child_weight  params_n_estimators  params_subsample     state
# 0                      215                 3000               0.8  COMPLETE
# 1                      297                  200               0.7  COMPLETE
# 2                      172                  200               0.6  COMPLETE
# 3                      136                 3000               1.0  COMPLETE
# 4                        1                  150               0.6  COMPLETE

# %%
study.best_params
# Out:
# {'lambda': 0.001029078601455882,
#  'alpha': 0.4986209509535147,
#  'colsample_bytree': 1.0,
#  'subsample': 0.8,
#  'learning_rate': 0.016,
#  'n_estimators': 300,
#  'max_depth': 13,
#  'min_child_weight': 29}

# %%
best_params = study.best_params
best_params['tree_method'] = 'gpu_hist'
best_params['random_state'] = 42

clf = xgb.XGBRegressor(**(best_params))

clf.fit(x_train, y_train)
# Out:
# XGBRegressor(alpha=0.4986209509535147, base_score=0.5, booster='gbtree',
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1.0,
#              gamma=0, gpu_id=0, importance_type='gain',
#              interaction_constraints='', lambda=0.001029078601455882,
#              learning_rate=0.016, max_delta_step=0, max_depth=13,
#              min_child_weight=29, missing=nan, monotone_constraints='()',
#              n_estimators=300, n_jobs=2, num_parallel_tree=1, random_state=42,
#              reg_alpha=0.498620957, reg_lambda=0.00102907862,
#              scale_pos_weight=1, subsample=0.8, tree_method='gpu_hist',
#              validate_parameters=1, verbosity=None)

# %%
predictions = clf.predict(x_test)
errors = abs(predictions - y_test)
print('Mean Absolute Error:', round(np.mean(errors), 3))
# Out:
# Mean Absolute Error: 0.052

# %%
filename = 'model.sav'
pickle.dump(clf, open(filename, 'wb'))

# %%
def predict(data):
    data = pd.DataFrame(data, columns = ['Gender', 'Company Type', 'WFH Setup Available', 'Designation','Resource Allocation', 'Mental Fatigue Score'])
    model = pickle.load(open('model.sav', 'rb'))
    prediction = model.predict(data)
    print('Burn Rate: ', prediction[0])

# %%
data = [[0, 1, 0, 2.0, 4.0, 6.8]]
predict(data)
# Out:
# Burn Rate:  0.508228
